# %%
import voltaiq_studio as vs

# %%
vs.get_test_records()
# Out:
# [TestRecord(id=51144, uuid='f049da5c-6226-4f6a-9930-a9314a94d699', name='HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_l_timeseriesvdf_cycleadjusted', device_id=11288, start_time=datetime.datetime(2013, 5, 25, 8, 0, 11, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), total_cycles=1087, status='DONE', time_series_query=TimeSeriesQuery(id=51144, action='time_series', trace_keys=[], info_keys=[], cycle_numbers=[], cycle_ranges=[], step_indexes=[], step_types=[], trace_filters=[]), cycle_stat_query=CycleStatQuery(test_record_id=51144, test_record_uuid='f049da5c-6226-4f6a-9930-a9314a94d699', action='cycle_stat')),
# ...
